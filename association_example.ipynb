# %% [markdown]
# # This notebook provides an example script for running association test

# %%
# load modules
from tqdm import tqdm

import csv
import pandas as pd
import numpy as np

import math
import random
import statsmodels.api as sm
from sklearn import preprocessing
import statsmodels.stats.multitest
import subprocess
import matplotlib.pyplot as plt

import sys
import cyvcf2

# %%
# helper functions
def getLineCount(filename):
    try:
        # Run wc -l command to count lines in the file
        result = subprocess.run(['wc', '-l', filename], capture_output=True, text=True, check=True)
        # Extract the line count from the output
        line_count = int(result.stdout.split()[0])
        return line_count
    except subprocess.CalledProcessError:
        # Handle errors, such as file not found
        print("Error: File not found or command failed.")
        return None

def getData(filename):
    with open(filename, "r") as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            yield row

def exonstrSLR(chrom,Pop,files_dir,minTs=10,mingt=3,minsPgt=3,search_range=100_000):
    """
    Pop: population 
    minTs: minimum samples required for regression
    mingt: minimum genotypes required for regression
    minsPgt: minimum samples requried for genotypes to be included in regression
    search_range: ranges search for associated STRs
    """

    #load covariates
    cov_df=pd.read_csv(f'{files_dir}/covariates_all.csv',sep='\t',index_col='sample_id')
    exp_df=pd.read_csv(f'{files_dir}/'+Pop+'_normalized_and_filtered_hg38_chr'+str(chrom)+'.csv',sep='\t')
    gt_dir=f'{files_dir}/chr'+str(chrom)+'.GB.FORMAT'
    
    csv_gen = getData(gt_dir)
    total_gt_n=getLineCount(gt_dir)
    row_count = 0
    p_df = pd.DataFrame(columns =[ "str-gene","str_end","motif","gene_name", \
        "sample_n","GT_n","p_values","slope",'error',"shuffled_p", \
            "shuffled_slope","shuffled_error"])
    
    p_df_list = []
    
    #the total length just for illustration purpose, can remove tqdm when running in large batches
    for row in tqdm(csv_gen,total=total_gt_n):
        if row_count==0:
            #extract sample name of current STR
            col_name=row[0].split('\t')
            row_count+=1
            continue

        gt_value=list(filter(lambda a: a!='',row[0].split('\t')))
        gt_df=pd.DataFrame([gt_value],columns=col_name)
        gt_df[gt_df.columns[4:]]=gt_df[gt_df.columns[4:]]. \
                applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
        gt_samples=gt_df.columns[4:][gt_df.iloc[0,4:].apply(lambda x: x !=[None,None])].to_list()
        gt_psi_samples=list(set(exp_df.columns[5:]) & set(gt_samples))
        #STR GENOTYPE FILTER
        gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
        gt_sum=gt_psi_phased.groupby('GT').size()

        #get joint data
        gt_ab_3=gt_sum[gt_sum>=minsPgt].index.tolist()
        #check number of genotype and check how many samples remains
        if len(gt_ab_3)<mingt or gt_sum[gt_ab_3].sum()<minTs:
            row_count+=1
            continue

        gt_psi_filted_samples=set(gt_psi_phased[gt_psi_phased.GT.isin(gt_ab_3)].index) & set(cov_df.index)
        gt_psi_samples=list(gt_psi_filted_samples)

        gt_df=gt_df[gt_df.columns[0:4].to_list()+gt_psi_samples]
        joint_cov_df=cov_df.loc[gt_psi_samples]
        joint_exp_df=exp_df[exp_df.columns[0:5].tolist()+gt_psi_samples]
        joint_exp_df=joint_exp_df[joint_exp_df.chromosome.values == gt_df['CHROM'].values]

        paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
                        & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]

        if paired_df.empty:
            row_count+=1
            continue

        for index, curr_exon in paired_df.iterrows():
            #contat the PSI, genotype, peer and pc for current exon of all samples
            a=pd.concat([curr_exon[5:].astype('float64'),\
                    gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
                    joint_cov_df],\
                    axis=1).rename(columns={index:'exp'})
            
            a=a[~a.exp.isnull()]
            
            #standardization
            a_scaled = preprocessing.StandardScaler().fit_transform(a)
            y=a_scaled[:,0]
            x=a_scaled[:,1:]
            x=sm.add_constant(x)
            mod_ols  = sm.OLS(y,x)
            res_ols = mod_ols.fit()
            p_values=res_ols.pvalues[1]
            slope=res_ols.params[1]
            err=res_ols.bse[1]

            shuffled_y = random.sample(list(y),len(y))
            mod_ols_s = sm.OLS(shuffled_y,x)
            res_ols_s = mod_ols_s.fit()
            shuffled_p=res_ols_s.pvalues[1]
            slope_p=res_ols_s.params[1]
            err_p=res_ols_s.bse[1]

            p_df_list.append(pd.DataFrame({"str-gene":[list(gt_df.CHROM +'_'+ gt_df.POS.str.rstrip()+'-'+curr_exon.gene_id)[0]],
                                "str_end":[gt_df.END.tolist()[0]],
                                "motif":[gt_df.motif.tolist()[0]],
                                "gene_name":[curr_exon.gene_name],
                                "sample_n":[len(a)],
                                "GT_n":[len(gt_ab_3)],
                                "p_values":[p_values],
                                "slope":[slope],
                                "error":[err],
                                "shuffled_p":[shuffled_p],
                                "shuffled_slope":[slope_p],
                                "shuffled_error":[err_p]}))
            
            p_df = pd.concat(p_df_list, ignore_index = True)
            
            row_count+=1

    return p_df

# %%
#directory where association files are located
reg_file_dir="files_for_association"

# %% [markdown]
# ### Running regression for CSTB

# %%
#running regression for CSTB
reg_results_cstb = exonstrSLR(21,"AFR",reg_file_dir)
# Out:
#   0%|          | 0/1067 [00:00<?, ?it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   0%|          | 2/1067 [00:00<05:48,  3.06it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   0%|          | 3/1067 [00:05<37:12,  2.10s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   0%|          | 4/1067 [00:06<30:48,  1.74s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   0%|          | 5/1067 [00:07<24:45,  1.40s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   1%|          | 6/1067 [00:07<20:44,  1.17s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   1%|          | 7/1067 [00:12<40:22,  2.28s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   1%|          | 8/1067 [00:13<32:42,  1.85s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   1%|          | 9/1067 [00:15<35:45,  2.03s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   1%|          | 10/1067 [00:18<39:19,  2.23s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   1%|          | 11/1067 [00:19<31:38,  1.80s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   1%|          | 12/1067 [00:20<29:52,  1.70s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   1%|          | 13/1067 [00:21<22:26,  1.28s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   1%|▏         | 14/1067 [00:21<17:46,  1.01s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   1%|▏         | 15/1067 [00:22<18:21,  1.05s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   1%|▏         | 16/1067 [00:23<15:05,  1.16it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   2%|▏         | 17/1067 [00:23<13:35,  1.29it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   2%|▏         | 18/1067 [00:24<14:25,  1.21it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   2%|▏         | 19/1067 [00:26<18:49,  1.08s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   2%|▏         | 20/1067 [00:26<16:43,  1.04it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   2%|▏         | 21/1067 [00:28<19:29,  1.12s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   2%|▏         | 22/1067 [00:28<15:58,  1.09it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   2%|▏         | 23/1067 [00:29<13:52,  1.25it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   2%|▏         | 24/1067 [00:31<19:12,  1.11s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   2%|▏         | 25/1067 [00:31<16:27,  1.06it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   2%|▏         | 26/1067 [00:32<13:59,  1.24it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   3%|▎         | 27/1067 [00:32<11:14,  1.54it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   3%|▎         | 28/1067 [00:33<10:28,  1.65it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   3%|▎         | 29/1067 [00:33<11:40,  1.48it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   3%|▎         | 30/1067 [00:34<10:28,  1.65it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   3%|▎         | 31/1067 [00:34<09:18,  1.85it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   3%|▎         | 32/1067 [00:34<07:43,  2.23it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   3%|▎         | 33/1067 [00:35<09:34,  1.80it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   3%|▎         | 34/1067 [00:36<08:11,  2.10it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   3%|▎         | 35/1067 [00:36<06:55,  2.48it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   3%|▎         | 36/1067 [00:37<09:16,  1.85it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   3%|▎         | 37/1067 [00:38<12:53,  1.33it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   4%|▎         | 38/1067 [00:39<16:12,  1.06it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   4%|▎         | 39/1067 [00:40<15:58,  1.07it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   4%|▎         | 40/1067 [00:40<12:52,  1.33it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   4%|▍         | 41/1067 [00:41<10:06,  1.69it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   4%|▍         | 42/1067 [00:41<08:40,  1.97it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   4%|▍         | 43/1067 [00:41<08:20,  2.05it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   4%|▍         | 44/1067 [00:42<07:43,  2.21it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   4%|▍         | 45/1067 [00:42<07:08,  2.39it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   4%|▍         | 46/1067 [00:42<06:12,  2.74it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   4%|▍         | 47/1067 [00:43<05:53,  2.89it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   4%|▍         | 48/1067 [00:43<06:34,  2.58it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   5%|▍         | 49/1067 [00:44<08:01,  2.11it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   5%|▍         | 50/1067 [00:45<09:56,  1.70it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   5%|▍         | 51/1067 [00:45<10:17,  1.65it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   5%|▍         | 52/1067 [00:46<08:30,  1.99it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   5%|▍         | 53/1067 [00:46<07:22,  2.29it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   5%|▌         | 54/1067 [00:46<07:40,  2.20it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#   5%|▌         | 55/1067 [00:47<10:06,  1.67it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#   5%|▌         | 56/1067 [00:48<08:25,  2.00it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# ...
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  98%|█████████▊| 1047/1067 [15:26<00:13,  1.45it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  98%|█████████▊| 1048/1067 [15:26<00:12,  1.50it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#  98%|█████████▊| 1049/1067 [15:27<00:14,  1.21it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  98%|█████████▊| 1050/1067 [15:28<00:11,  1.51it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  99%|█████████▊| 1051/1067 [15:28<00:08,  1.92it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  99%|█████████▊| 1052/1067 [15:28<00:06,  2.19it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#  99%|█████████▊| 1053/1067 [15:30<00:09,  1.42it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  99%|█████████▉| 1054/1067 [15:30<00:08,  1.62it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  99%|█████████▉| 1055/1067 [15:30<00:06,  1.74it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  99%|█████████▉| 1056/1067 [15:31<00:05,  1.87it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#  99%|█████████▉| 1057/1067 [15:34<00:11,  1.18s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  99%|█████████▉| 1058/1067 [15:34<00:08,  1.09it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#  99%|█████████▉| 1059/1067 [15:36<00:09,  1.16s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
#  99%|█████████▉| 1060/1067 [15:38<00:10,  1.52s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
#  99%|█████████▉| 1061/1067 [15:39<00:07,  1.27s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# 100%|█████████▉| 1062/1067 [15:39<00:05,  1.04s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# 100%|█████████▉| 1063/1067 [15:40<00:03,  1.10it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# /tmp/ipykernel_23281/2580154010.py:76: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   paired_df=joint_exp_df[(joint_exp_df.start - search_range <= int(gt_df.POS)) \
# /tmp/ipykernel_23281/2580154010.py:77: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   & (joint_exp_df.end + search_range >= (int(gt_df.POS)))]
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# /tmp/ipykernel_23281/2580154010.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x)),\
# 100%|█████████▉| 1064/1067 [15:42<00:03,  1.28s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# 100%|█████████▉| 1065/1067 [15:43<00:02,  1.12s/it]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# 100%|█████████▉| 1066/1067 [15:43<00:00,  1.06it/s]/tmp/ipykernel_23281/2580154010.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_23281/2580154010.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gt_psi_phased=gt_df[gt_psi_samples].T.rename(columns={0:'GT'}).applymap(lambda x: sum(x))
# 100%|██████████| 1067/1067 [15:44<00:00,  1.13it/s]

# %%
# see top hits
reg_results_cstb.sort_values(by='p_values')
# Out:
#                               str-gene   str_end         motif gene_name  \
# 616   chr21_43776445-ENSG00000160213.5  43776481         GCGGG      CSTB
# 611   chr21_43776443-ENSG00000160213.5  43776478  GCGCGGGGCGGG      CSTB
# 136   chr21_42904492-ENSG00000160199.8  42904510             T    PKNOX1
# 84    chr21_42871991-ENSG00000160193.7  42872001             T      WDR4
# 140   chr21_42907449-ENSG00000160193.7  42907469             T      WDR4
# ..                                 ...       ...           ...       ...
# 269  chr21_42999475-ENSG00000160200.12  42999498         TTTTC       CBS
# 538  chr21_43724682-ENSG00000160209.12  43724695             A      PDXK
# 563  chr21_43736630-ENSG00000160209.12  43736649             T      PDXK
# 37   chr21_42811264-ENSG00000160194.11  42811290             T    NDUFV3
# 182   chr21_42948294-ENSG00000160193.7  42948318             T      WDR4
#
#      sample_n  GT_n      p_values     slope     error  shuffled_p  \
# 616        89     3  1.022722e-08  0.772511  0.100999    0.013080
# 611        89     3  1.022722e-08  0.772511  0.100999    0.570050
# 136        88     6  1.873399e-04  0.548134  0.129315    0.224841
# 84         89     3  5.329217e-04 -0.360057  0.093524    0.719383
# 140        87     5  1.309374e-03 -0.313768  0.088504    0.113834
# ..        ...   ...           ...       ...       ...         ...
# 269        89     3  9.921196e-01 -0.001252  0.125738    0.713108
# 538        89     3  9.965180e-01 -0.000632  0.143616    0.961497
# 563        85     4  9.970224e-01  0.000583  0.154788    0.334315
# 37         87     5  9.981653e-01  0.000410  0.176933    0.888265
# 182        85     3  9.991804e-01  0.000142  0.137269    0.742120
#
#      shuffled_slope  shuffled_error
# 616        0.330912        0.125917
# 611        0.087521        0.152503
# 136        0.210772        0.170189
# 84        -0.056744        0.156547
# 140        0.223448        0.137194
# ..              ...             ...
# 269        0.072462        0.195334
# 538       -0.007990        0.164219
# 563        0.182945        0.186222
# 37        -0.027236        0.192214
# 182        0.066202        0.199208
#
# [1346 rows x 12 columns]

# %%
threshold = 0.05

reg_results_cstb['str_end'] = reg_results_cstb['str_end'].astype(int)
reg_results_cstb['-log10_p_values'] = -np.log10(reg_results_cstb['p_values'])

plt.figure(figsize=(10, 6))
plt.scatter(reg_results_cstb['str_end'], reg_results_cstb['-log10_p_values'], alpha=0.5)

unique_names = set()

for index, row in reg_results_cstb.iterrows():
    if row['p_values'] < threshold:
        if (row['gene_name']) not in unique_names:
            unique_names.add((row['gene_name']))
            plt.text(row['str_end'], row['-log10_p_values'], f"{row['gene_name']}", fontsize=8, ha='left')

# dashed line
plt.axhline(-np.log10(0.05), color='red', linestyle='--')

plt.xlabel('Chromosome 21')
plt.ylabel("$-log_{10}$ (p-values)")

x_ticks = np.arange(reg_results_cstb['str_end'].min(), reg_results_cstb['str_end'].max() + 1, 300000)
plt.xticks(x_ticks)
plt.ticklabel_format(style='plain')
plt.show()

# %%
reg_results_cstb.query("p_values <= 0.05").sort_values(by='p_values')['gene_name'].unique()
# Out:
# array(['CSTB', 'PKNOX1', 'WDR4', 'HSF2BP', 'PDXK', 'C21orf2', 'RRP1',
#        'AP001055.7', 'TRPM2', 'NDUFV3', 'PFKL', 'AGPAT3', 'RRP1B',
#        'PDE9A', 'AIRE', 'PWP2', 'LRRC3', 'TRAPPC10', 'U2AF1'],
#       dtype=object)

# %% [markdown]
# ### Running regression for TIMM10

# %%
reg_results_timm10 = exonstrSLR(11, "AFR", reg_file_dir)

# %%
reg_results_timm10[ (reg_results_timm10.str_end == "57528517")]
# Out:
#                               str-gene   str_end motif gene_name  sample_n  \
# 182   chr11_57528484-ENSG00000186907.3  57528517    TA   RTN4RL2        82
# 183   chr11_57528484-ENSG00000149150.4  57528517    TA   SLC43A1        82
# 184   chr11_57528484-ENSG00000134809.4  57528517    TA    TIMM10        82
# 185   chr11_57528484-ENSG00000214872.4  57528517    TA    SMTNL1        82
# 186  chr11_57528484-ENSG00000156587.11  57528517    TA    UBE2L6        82
# 187  chr11_57528484-ENSG00000149131.10  57528517    TA  SERPING1        82
#
#      GT_n  p_values     slope     error  shuffled_p  shuffled_slope  \
# 182     6  0.499687 -0.106053  0.154836    0.478697        0.119223
# 183     6  0.115983  0.251694  0.154567    0.945757       -0.016565
# 184     6  0.000007  0.500930  0.088372    0.586209        0.111285
# 185     6  0.465625 -0.113758  0.153530    0.829706        0.043035
# 186     6  0.511413 -0.065684  0.098601    0.973376        0.007621
# 187     6  0.915067  0.017163  0.159312    0.684330        0.087378
#
#      shuffled_error
# 182        0.165775
# 183        0.241041
# 184        0.201798
# 185        0.198005
# 186        0.226079
# 187        0.212424

# %%
# visualise results
def get_str_exp_values(files_dir,str_gene, pop='AFR',minsPgt=3):
    """
    input str-gene pairs and population
    extract the genotypes: sum of alleles output the expression 
    """
    
    chrom=str_gene.split('_')[0]
    pos=int(str_gene.split('-')[0].split('_')[1])
    gene_id=str_gene.split('-')[1]

    exp_df=pd.read_csv(f'{files_dir}/'+pop+'_normalized_and_filtered_hg38_'+chrom+'.csv',sep='\t')
    gt_dir=f'{files_dir}/'+chrom+'.GB.FORMAT'
    
    exp_df=exp_df[exp_df.gene_id==gene_id]
    
    all_STR=pd.read_csv(gt_dir,sep='\t')
    select_STR=all_STR[all_STR.POS==pos].copy()
    select_STR[select_STR.columns[4:]]=select_STR[select_STR.columns[4:]]. \
                    applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
    select_STR=select_STR[['CHROM','POS']+select_STR.columns[4:][select_STR.iloc[0,4:].apply(lambda x: x !=[None,None])].to_list()]
    gt_samples=select_STR.columns[4:][select_STR.iloc[0,4:].apply(lambda x: x !=[None,None])].to_list()
    gt_samples=list(set(gt_samples) & set(exp_df.columns.tolist()))
    select_STR_phased=select_STR[gt_samples].T.rename \
                        (columns={select_STR.index.to_list()[0]:'GT'}).applymap(lambda x: sum(x))
    gt_sum=select_STR_phased.groupby('GT').size()
    gt_ab_3=gt_sum[gt_sum>=minsPgt].index.tolist()
    final_filted_samples=set(select_STR_phased[select_STR_phased.GT.isin(gt_ab_3)].index)
    final_filted_samples_list = list(final_filted_samples)
    final_phased_STR=select_STR_phased.loc[final_filted_samples_list].copy()
    
    return final_phased_STR.values.reshape(-1),exp_df[final_filted_samples_list].values.reshape(-1)

def GetSummary(gts, exprs):
    gtvals = sorted(list(set(gts)))
    evals = []
    for gtval in gtvals:
        evals.append(np.median([exprs[i] for i in range(len(exprs)) if gts[i]==gtval]))
    return gtvals, evals

def plot_eTR(str_gene,ax,motif,gene_name,file_dir):
    afr_str, afr_expr = get_str_exp_values(file_dir,str_gene,pop='AFR')
    afr_str_summ, afr_expr_summ = GetSummary(afr_str, afr_expr)

    ax.scatter(afr_str,afr_expr,color='red', alpha=0.2,s=20) 
    ax.plot(afr_str_summ, afr_expr_summ, color="red", marker="o", label="AFR")

    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    ax.legend()
    ax.set_xlabel("bp diff from hg38")
    ax.set_ylabel("Normalized expression")
    ax.set_title("%s (%s)"%(gene_name, motif),fontsize=20)

# %%
fig, ax = plt.subplots()
plot_eTR("chr11_57528484-ENSG00000134809.4", ax, "TA", "TIMM10", reg_file_dir)
# Out:
# /tmp/ipykernel_542659/3152524879.py:20: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   applymap(lambda x: [int(x.split('/')[0]),int(x.split('/')[1])] if '/' in x else [None,None])
# /tmp/ipykernel_542659/3152524879.py:25: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   (columns={select_STR.index.to_list()[0]:'GT'}).applymap(lambda x: sum(x))
